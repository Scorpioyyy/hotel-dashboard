# %% [markdown]
# # 使用示例

# %%
import os
from pathlib import Path
from lib import HotelReviewRAG, print_rag_result

# 项目路径配置
PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print(f"离线数据目录: {DATA_DIR}")

# 检查环境变量
required_env = {
    "DASHSCOPE_API_KEY": os.getenv("DASHSCOPE_API_KEY"),
    "DASHVECTOR_API_KEY": os.getenv("DASHVECTOR_API_KEY"),
    "DASHVECTOR_HOTEL_ENDPOINT": os.getenv("DASHVECTOR_HOTEL_ENDPOINT"),
}

missing = [k for k, v in required_env.items() if not v]
if missing:
    raise EnvironmentError(f"缺少环境变量: {', '.join(missing)}")

print("环境变量检测成功:")
for key, value in required_env.items():
    print(f"- {key}: {value[:10]}...{value[-4:]}")
# Out:
# 离线数据目录: C:\Users\22418\Desktop\Scorpio\复旦\课程\大三下\酒店评论\data
# 环境变量检测成功:
# - DASHSCOPE_API_KEY: sk-5540c66...f37a
# - DASHVECTOR_API_KEY: sk-W6G93uB...7EDE
# - DASHVECTOR_HOTEL_ENDPOINT: vrs-cn-zks....com

# %%
# 初始化 RAG 系统
rag_system = HotelReviewRAG(
    api_key=required_env["DASHSCOPE_API_KEY"],
    dashvector_api_key=required_env["DASHVECTOR_API_KEY"],
    dashvector_endpoint=required_env["DASHVECTOR_HOTEL_ENDPOINT"],
    data_dir=DATA_DIR
)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\22418\AppData\Local\Temp\jieba.cache
# Loading model cost 0.687 seconds.
# Prefix dict has been built successfully.
# 倒排索引已加载

# %%
# 测试用例
test_query = "套房空间大吗？"
result = rag_system.query(test_query, enable_hyde=False)
print_rag_result(result)
# Out:
# 根据近期住客的反馈，花园酒店的套房在空间方面普遍获得了积极评价。
#
# **空间感受：宽敞舒适**
# 多数住客认为套房面积宽敞、布局合理。有多条评论直接提及“房间超大”、“套房面积大”、“宽敞舒适”。例如，有住客提到其预订的套房面积为64平方米，感觉非常宽敞（评论9/10），也有住客称赞“客厅好大”（评论1）。
#
# **内部格局：功能分区**
# 套房通常设有独立的客厅区域，实现了卧室与客厅的功能分区，提升了居住的舒适度和便利性。
#
# **温馨提示**
# 需要注意的是，空间感受可能存在个体差异。例如，有少数住客在称赞客厅大的同时，感觉卧室空间相对小一些（评论1）。此外，套房的具体布局和面积可能因房型和装修批次而略有不同。
#
# 总体而言，从现有反馈看，花园酒店的套房能为您提供较为宽敞和舒适的居住空间。如果您对特定房型的面积或格局有更具体的要求，建议在预订时直接联系酒店前台进行确认。
#
# ⏱️  延迟统计:
#   • 查询处理（不含HyDE）: 1.460s
#     • 意图识别: 0.409s
#     • 意图检测: 1.049s
#     • 意图扩展: 0.946s
#   • 混合检索: 0.527s
#     • 文本召回: 0.009s
#     • 向量召回: 0.513s
#     • 反向召回: 0.512s
#     • HyDE召回: 0.000s
#     • 摘要召回: 0.479s
#     • RRF融合: 0.013s
#   • 排序: 0.537s（Rerank 0.532s + 排序 0.005s）
#   • 模型回复: 7.477s
#     • 首字延迟: 0.864s
#     • 后续回复: 6.613s
#   • 首字延迟: 3.388s
#   • 总延迟: 10.001s
#
# 🔍 查询处理:
#   • 意图检测: {'room_type': None, 'fuzzy_room_type': '套房', 'time_sensitivity': None}
#   • 意图扩展:
#       - 该套房的建筑面积有多大？ (weight=0.6)
#       - 套房内是否有独立的客厅区域？ (weight=0.4)
#
# 🔮 未启用 HyDE 召回
#
# 📚 召回摘要类别 (1个):
#   [1] 景观/朝向（被 Query [0, 1] 召回）
#       关键词: 瀑布花园景观,城市天际线/小蛮腰远眺,岭南园林风格,房间窗景优越,后花园/庭院优美,旋转餐厅视野
#       评论数: 88
#       摘要: 在景观/朝向方面，该酒店的突出优势在于其独特且丰富的内外景观。内部景观以标志性的瀑布花园为核心，多数评论称赞房间窗户正对瀑布与花木，营造出“花团锦簇”、“春意盎然”的园林意境，后花园的岭南园林设计、小...
#
# 🏆 Top 10 评论:
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 1 | 综合得分: 0.6604
#   检索排名: # 2 | 检索得分: 0.0384 | Rerank排名: # 3 | Rerank得分: 0.7385
#   评论ID: 680278efe3c98b094176575a
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 5 | 评论: 70 | 点赞: 0 | 发布: 2025-03-04
#   排序: 0.6604 = 0.4 * 0.739（相关）+ 0.25 * 0.500（质量）+ 0.05 * 0.585（长度）+ 0.05 * 0.674（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.885（时效）
#   内容: 设施：设施齐全，看着都挺新的
# 卫生：干净卫生
# 环境：附近就是北京路吃吃喝喝挺多的
# 服务：挺好的
# 定的套房客厅好大，房间稍微感觉小了一些些
# 早餐没去吃，下次去尝尝
#   召回路由:
#     • 反向: 第1名(Q1), 第12名(Q0)
#     • 向量: 第3名(Q0), 第47名(Q1)
#     • 文本: 第9名(Q1), 第74名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 2 | 综合得分: 0.6574
#   检索排名: # 1 | 检索得分: 0.0419 | Rerank排名: # 1 | Rerank得分: 0.8149
#   评论ID: 68027e37e3c98b0941765bd9
#   房型: 红棉双床套房（套房）
#   评分: 5.0 | 质量: 9 | 评论: 77 | 点赞: 0 | 发布: 2023-09-17
#   排序: 0.6574 = 0.4 * 0.815（相关）+ 0.25 * 0.900（质量）+ 0.05 * 0.636（长度）+ 0.05 * 0.689（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.201（时效）
#   内容: 这个套票很超值。套房面积大，装饰富有岭南特色，注重细节。大大的写字台面甚至有木棉花的隐花纹。双洗手台，洗手台、马桶间和洗浴间三分离。大大的观景窗，窗外是广州的繁华夜景。套票里的500元餐券用在了岭南特色餐厅荔湾亭，毕竟是米其林指南餐厅。
#   召回路由:
#     • 反向: 第1名(Q0), 第18名(Q0), 第18名(Q1), 第30名(Q1)
#     • 向量: 第6名(Q0), 第108名(Q1)
#     • 文本: 第123名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 3 | 综合得分: 0.6390
#   检索排名: #28 | 检索得分: 0.0230 | Rerank排名: # 8 | Rerank得分: 0.6565
#   评论ID: 680279aae3c98b09417657f9
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 7 | 评论: 4 | 点赞: 0 | 发布: 2025-02-04
#   排序: 0.6390 = 0.4 * 0.656（相关）+ 0.25 * 0.700（质量）+ 0.05 * 0.498（长度）+ 0.05 * 0.255（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.819（时效）
#   内容: 订的红棉大床房给我升级了行政套房，房间超大，很不错，服务也挺好，对小朋友也很热情！
#   召回路由:
#     • 文本: 第13名(Q0), 第80名(Q1)
#     • 向量: 第14名(Q0), 第46名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 4 | 综合得分: 0.6205
#   检索排名: #48 | 检索得分: 0.0175 | Rerank排名: # 4 | Rerank得分: 0.7257
#   评论ID: 6802835fe3c98b0941766041
#   房型: 红棉大床套房（套房）
#   评分: 4.7 | 质量: 8 | 评论: 30 | 点赞: 0 | 发布: 2024-04-05
#   排序: 0.6205 = 0.4 * 0.726（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.657（长度）+ 0.05 * 0.543（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.351（时效）
#   内容: 一间老牌国宾馆，名气大，设施好，近地铁，附近没有什么食肆，酒店内的人造瀑布非常漂亮，拍照位甚多，我们订的套房很舒适，面积大，床上和洗澡用品亦好，设备齐全，唯一就是 check in 取房排队时间较长，等了差不多 45分钟，但大堂又没有什么梳化坐椅给客人休息，这点可以改善一下。
#   召回路由:
#     • 向量: 第23名(Q0), 第50名(Q1)
#     • 文本: 第119名(Q0)
#     • 反向: 第121名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 5 | 综合得分: 0.6149
#   检索排名: #93 | 检索得分: 0.0113 | Rerank排名: #29 | Rerank得分: 0.4771
#   评论ID: 6802794be3c98b09417657ac
#   房型: 红棉双床套房（套房）
#   评分: 4.0 | 质量: 8 | 评论: 26 | 点赞: 4 | 发布: 2024-12-17
#   排序: 0.6149 = 0.4 * 0.477（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.659（长度）+ 0.05 * 0.521（评论）+ 0.05 * 0.442（点赞）+ 0.2 * 0.715（时效）
#   内容: 大堂美丽气派。红棉套房，新装修的，漂亮温馨。居住舒适。前台YOLO小姑娘热情解答各种问题。
# 涉外酒店??老外很多。感觉对内宾没有对外宾热情??
# 早餐自助瀑布餐厅人太多了，还没用完餐，桌子就被占领了??周围在施工有点不便。
# 西餐厅ZONA LIANG 非常热情，一直帮着拍照????
#   召回路由:
#     • 向量: 第49名(Q1), 第75名(Q0)
#     • 文本: 第127名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 6 | 综合得分: 0.6128
#   检索排名: #85 | 检索得分: 0.0119 | Rerank排名: #37 | Rerank得分: 0.4653
#   评论ID: 6802789fe3c98b0941765719
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 8 | 评论: 7 | 点赞: 0 | 发布: 2025-03-10
#   排序: 0.6128 = 0.4 * 0.465（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.605（长度）+ 0.05 * 0.329（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.900（时效）
#   内容: 房间够大～布局合理～餐食美味～一四楼的酒店博物馆很有历史年代感～天气凉没下水～泳池还是很不错滴后花园很出片～最喜欢的是酒店到处都是鲜花布置～体现了广州花都的花园酒店～非常完美的一次选择～
#   召回路由:
#     • 向量: 第45名(Q0), 第45名(Q1)
#     • 反向: 第108名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 7 | 综合得分: 0.6096
#   检索排名: # 5 | 检索得分: 0.0359 | Rerank排名: #10 | Rerank得分: 0.5872
#   评论ID: 680279d6e3c98b0941765822
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 8 | 评论: 5 | 点赞: 0 | 发布: 2024-11-18
#   排序: 0.6096 = 0.4 * 0.587（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.573（长度）+ 0.05 * 0.284（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.659（时效）
#   内容: 入住顺利，帮我们升级了行政套房，房间很大，还配备了瑜伽垫，服务周到。卫生间的各项设施完备，餐厅的早餐也不错。不足的地方在于，房间里的电视不能联网。
#   召回路由:
#     • 向量: 第8名(Q0), 第8名(Q1)
#     • 反向: 第17名(Q1), 第34名(Q0), 第77名(Q1)
#     • 文本: 第70名(Q0), 第136名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 8 | 综合得分: 0.5963
#   检索排名: #36 | 检索得分: 0.0202 | Rerank排名: #64 | Rerank得分: 0.4143
#   评论ID: 680278c1e3c98b0941765734
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 8 | 评论: 10 | 点赞: 0 | 发布: 2025-03-14
#   排序: 0.5963 = 0.4 * 0.414（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.593（长度）+ 0.05 * 0.379（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.910（时效）
#   内容: 趁老公生日的机会，选择在花园酒店度过愉快的一晚，红棉套房套餐体验很好，提前备注酒店帮忙做了生日布置，还送了小蛋糕。各个工作人员都很热情，特别是行政酒廊Louis服务热情。
#   召回路由:
#     • 反向: 第19名(Q0)
#     • 向量: 第76名(Q0), 第146名(Q1)
#     • 文本: 第79名(Q0), 第144名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 9 | 综合得分: 0.5889
#   检索排名: #34 | 检索得分: 0.0205 | Rerank排名: # 2 | Rerank得分: 0.7509
#   评论ID: 68027c4be3c98b0941765a37
#   房型: 红棉双床套房（套房）
#   评分: 5.0 | 质量: 7 | 评论: 17 | 点赞: 0 | 发布: 2024-02-07
#   排序: 0.5889 = 0.4 * 0.751（相关）+ 0.25 * 0.700（质量）+ 0.05 * 0.618（长度）+ 0.05 * 0.457（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.299（时效）
#   内容: 酒店非常气派，大开眼界！ 长辈都夸好。
# 定的64平的套房，宽敞舒适，客房服务响应及时，行李搬运也到位。
# 第一天图省事去了荔湾艇吃饭，有点不愉快，性价比不高。
# 下次还会选择入住花园酒店，吃饭还是去外面吃更好。
#   召回路由:
#     • 反向: 第8名(Q0)
#     • 向量: 第15名(Q0)
#     • 文本: 第103名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: #10 | 综合得分: 0.5874
#   检索排名: #66 | 检索得分: 0.0141 | Rerank排名: #13 | Rerank得分: 0.5577
#   评论ID: 68027aa2e3c98b09417658ca
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 9 | 评论: 2 | 点赞: 0 | 发布: 2024-08-11
#   排序: 0.5874 = 0.4 * 0.558（相关）+ 0.25 * 0.900（质量）+ 0.05 * 0.611（长度）+ 0.05 * 0.174（评论）+ 0.05 * 0.000（点赞）+ 0.2 * 0.501（时效）
#   内容: 房间64平，宽敞。服务热情周到。环境优美，装修大气，作为白金五星酒店性价比很高，出行方便，只要不去长隆玩，离广州所有玩的地方，像永庆坊，陈家祠，海心沙，沙面，北京路，圣心大教堂，珠江夜游都不远。
#   召回路由:
#     • 向量: 第35名(Q0), 第143名(Q1)
#     • 反向: 第43名(Q0)

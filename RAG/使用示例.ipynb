# %% [markdown]
# # 使用示例

# %%
import os
from pathlib import Path
from lib import HotelReviewRAG, print_rag_result

# 项目路径配置
PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print(f"离线数据目录: {DATA_DIR}")

# 检查环境变量
required_env = {
    "DASHSCOPE_API_KEY": os.getenv("DASHSCOPE_API_KEY"),
    "DASHVECTOR_API_KEY": os.getenv("DASHVECTOR_API_KEY"),
    "DASHVECTOR_HOTEL_ENDPOINT": os.getenv("DASHVECTOR_HOTEL_ENDPOINT"),
}

missing = [k for k, v in required_env.items() if not v]
if missing:
    raise EnvironmentError(f"缺少环境变量: {', '.join(missing)}")

print("环境变量检测成功:")
for key, value in required_env.items():
    print(f"- {key}: {value[:10]}...{value[-4:]}")
# Out:
# 离线数据目录: C:\Users\22418\Desktop\Scorpio\复旦\课程\大三下\酒店评论\data
# 环境变量检测成功:
# - DASHSCOPE_API_KEY: sk-5540c66...f37a
# - DASHVECTOR_API_KEY: sk-W6G93uB...7EDE
# - DASHVECTOR_HOTEL_ENDPOINT: vrs-cn-e4k....com

# %%
# 初始化 RAG 系统
rag_system = HotelReviewRAG(
    api_key=required_env["DASHSCOPE_API_KEY"],
    dashvector_api_key=required_env["DASHVECTOR_API_KEY"],
    dashvector_endpoint=required_env["DASHVECTOR_HOTEL_ENDPOINT"],
    data_dir=DATA_DIR
)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\22418\AppData\Local\Temp\jieba.cache
# Loading model cost 0.611 seconds.
# Prefix dict has been built successfully.
# 倒排索引已加载

# %%
# 测试用例
test_query = "套房空间大吗？"
result = rag_system.query(test_query, enable_hyde=False)
print_rag_result(result)
# Out:
# 您好！关于广州花园酒店套房的空间，根据近期的住客评论，反馈普遍是比较宽敞的。以下是为您整理的信息：
#
# **1. 面积感受：多数住客评价“宽敞”**
# 从评论来看，住客对套房空间的主要印象是“大”、“宽敞”和“舒适”。例如，有住客提到升级后的套房面积比大床房“大一倍”（评论1），也有住客直接称赞“客厅好大”（评论2）或“房间超大”（评论4）。部分评论提供了具体数据，指出64平方米的套房“宽敞舒适”（评论9/10）。
#
# **2. 空间布局：通常设有独立的客厅或工作区**
# 套房通常意味着有更合理的功能分区。住客在评论中提到“大大的写字台面”（评论3）、“大大的观景窗”（评论3）以及配备了瑜伽垫（评论7），这反映出套房内普遍设有独立的休息、工作或活动区域，空间利用率较高。
#
# **3. 需注意的方面**
# 虽然多数评价正面，但也有个别住客提到“房间稍微感觉小了一些些”（评论2），这提示空间感受可能因具体套房格局或个人预期而略有差异。此外，根据酒店的整体设施评论摘要，客房体验与房型新旧程度相关，部分较老的基础房型可能存在设计局促的问题，但**翻新后的套房系列（如红棉套房）** 在空间和设施上普遍获得了更好的评价。
#
# **总结：**
# 综合近期住客反馈，广州花园酒店的套房（尤其是红棉套房等翻新房型）在空间上得到了“宽敞”、“面积大”的普遍认可，并通常具备功能分区的优势。如果您对空间有较高要求，建议在预订时选择明确标注为套房或行政套房的房型。
#
# 希望以上信息对您有帮助！如有其他具体需求，欢迎随时提出。
#
# ⏱️  延迟统计:
#   • 查询处理（不含HyDE）: 1.447s
#     • 意图识别: 0.420s
#     • 意图检测: 1.025s
#     • 意图扩展: 0.832s
#   • 混合检索: 0.426s
#     • 文本召回: 0.013s
#     • 向量召回: 0.403s
#     • 反向召回: 0.402s
#     • HyDE召回: 0.000s
#     • 摘要召回: 0.389s
#     • RRF融合: 0.021s
#   • 重排: 0.548s（Rerank 0.541s + 排序 0.007s）
#   • 模型回复: 10.333s
#     • 首字延迟: 0.900s
#     • 后续回复: 9.433s
#   • 首字延迟: 3.321s
#   • 总延迟: 12.754s
#
# 🔍 查询处理:
#   • 意图检测: {'room_type': None, 'fuzzy_room_type': '套房', 'time_sensitivity': None}
#   • 意图扩展:
#       - 套房的面积有多大？ (weight=0.8)
#       - 套房内是否有独立的休息区或工作区？ (weight=0.2)
#
# 🔮 未启用 HyDE 召回
#
# 📚 召回摘要类别 (1个):
#   [1] 房间设施（被 Query [0, 1] 召回）
#       关键词: 设施陈旧老化,空间布局不合理,装修风格与维护,隔音与噪音问题,设施故障与维护,部分房间翻新
#       评论数: 619
#       摘要: 根据619条关于房间设施的评论，住客的评价呈现出明显的两极分化。核心观点围绕设施的年代感、设计合理性和维护状况展开。
#
# **正面评价**主要集中在部分经过翻新的房型（如红棉房、粤韵套房）。住客称赞这些...
#
# 🏆 Top 10 评论:
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 1 | 综合得分: 0.6677
#   检索排名: #94 | 检索得分: 0.0121 | Rerank排名: # 4 | Rerank得分: 0.7444
#   评论ID: 68027b83e3c98b0941765986
#   房型: 花园大床房（大床房）
#   评分: 5.0 | 质量: 9 | 回复: 11 | 点赞: 2 | 发布: 2024-05-09
#   排序: 0.6677 = 0.4 * 0.744（相关）+ 0.25 * 0.900（质量）+ 0.05 * 0.661（长度）+ 0.05 * 0.393（回复）+ 0.05 * 0.302（点赞）+ 0.2 * 0.386（时效）
#   内容: 定的大床房，给升级了套房，套房的面积比大床房大一倍，没有到酒店之前很忐忑，因为看到评论说因为酒店旧所以有霉味，到了房间之后发现完全是多虑了，房间一点味道也没有，地理位置也很棒，打车去各景点大概都在30元以内，出酒店门就是地铁，周边吃的也很多，很多热门的店周边都有分店。这次住的很满意。
#   召回路由:
#     • 文本: 第15名(Q0), 第79名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 2 | 综合得分: 0.6664
#   检索排名: # 4 | 检索得分: 0.0343 | Rerank排名: # 2 | Rerank得分: 0.7536
#   评论ID: 680278efe3c98b094176575a
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 5 | 回复: 70 | 点赞: 0 | 发布: 2025-03-04
#   排序: 0.6664 = 0.4 * 0.754（相关）+ 0.25 * 0.500（质量）+ 0.05 * 0.585（长度）+ 0.05 * 0.674（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.885（时效）
#   内容: 设施：设施齐全，看着都挺新的
# 卫生：干净卫生
# 环境：附近就是北京路吃吃喝喝挺多的
# 服务：挺好的
# 定的套房客厅好大，房间稍微感觉小了一些些
# 早餐没去吃，下次去尝尝
#   召回路由:
#     • 反向: 第1名(Q0), 第1名(Q1)
#     • 向量: 第18名(Q0), 第48名(Q1)
#     • 文本: 第108名(Q0), 第131名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 3 | 综合得分: 0.6573
#   检索排名: # 1 | 检索得分: 0.0461 | Rerank排名: # 1 | Rerank得分: 0.8146
#   评论ID: 68027e37e3c98b0941765bd9
#   房型: 红棉双床套房（套房）
#   评分: 5.0 | 质量: 9 | 回复: 77 | 点赞: 0 | 发布: 2023-09-17
#   排序: 0.6573 = 0.4 * 0.815（相关）+ 0.25 * 0.900（质量）+ 0.05 * 0.636（长度）+ 0.05 * 0.689（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.201（时效）
#   内容: 这个套票很超值。套房面积大，装饰富有岭南特色，注重细节。大大的写字台面甚至有木棉花的隐花纹。双洗手台，洗手台、马桶间和洗浴间三分离。大大的观景窗，窗外是广州的繁华夜景。套票里的500元餐券用在了岭南特色餐厅荔湾亭，毕竟是米其林指南餐厅。
#   召回路由:
#     • 反向: 第15名(Q0), 第19名(Q0), 第22名(Q1), 第51名(Q1)
#     • 文本: 第16名(Q0)
#     • 向量: 第24名(Q0), 第130名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 4 | 综合得分: 0.6384
#   检索排名: #47 | 检索得分: 0.0185 | Rerank排名: # 9 | Rerank得分: 0.6550
#   评论ID: 680279aae3c98b09417657f9
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 7 | 回复: 4 | 点赞: 0 | 发布: 2025-02-04
#   排序: 0.6384 = 0.4 * 0.655（相关）+ 0.25 * 0.700（质量）+ 0.05 * 0.498（长度）+ 0.05 * 0.255（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.819（时效）
#   内容: 订的红棉大床房给我升级了行政套房，房间超大，很不错，服务也挺好，对小朋友也很热情！
#   召回路由:
#     • 向量: 第34名(Q0), 第125名(Q1)
#     • 文本: 第48名(Q0), 第71名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 5 | 综合得分: 0.6254
#   检索排名: #81 | 检索得分: 0.0135 | Rerank排名: # 7 | Rerank得分: 0.6950
#   评论ID: 68028542e3c98b0941766129
#   房型: 花园大床房（大床房）
#   评分: 5.0 | 质量: 8 | 回复: 125 | 点赞: 1 | 发布: 2024-04-02
#   排序: 0.6254 = 0.4 * 0.695（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.599（长度）+ 0.05 * 0.765（回复）+ 0.05 * 0.190（点赞）+ 0.2 * 0.348（时效）
#   内容: 早餐丰富，园景漂亮，漫步其中听瀑布观美景，整个人都放轻松了，房间面积大，床上用品舒服，唯一不足的是洗洛备品太次了，前一段时间套房还送宝格丽用的，现在和普通房一样，是不知道的品牌。
#   召回路由:
#     • 文本: 第4名(Q0), 第149名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 6 | 综合得分: 0.6209
#   检索排名: #43 | 检索得分: 0.0194 | Rerank排名: # 5 | Rerank得分: 0.7267
#   评论ID: 6802835fe3c98b0941766041
#   房型: 红棉大床套房（套房）
#   评分: 4.7 | 质量: 8 | 回复: 30 | 点赞: 0 | 发布: 2024-04-05
#   排序: 0.6209 = 0.4 * 0.727（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.657（长度）+ 0.05 * 0.543（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.351（时效）
#   内容: 一间老牌国宾馆，名气大，设施好，近地铁，附近没有什么食肆，酒店内的人造瀑布非常漂亮，拍照位甚多，我们订的套房很舒适，面积大，床上和洗澡用品亦好，设备齐全，唯一就是 check in 取房排队时间较长，等了差不多 45分钟，但大堂又没有什么梳化坐椅给客人休息，这点可以改善一下。
#   召回路由:
#     • 文本: 第14名(Q0)
#     • 向量: 第49名(Q1), 第59名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 7 | 综合得分: 0.6117
#   检索排名: # 3 | 检索得分: 0.0384 | Rerank排名: #10 | Rerank得分: 0.5927
#   评论ID: 680279d6e3c98b0941765822
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 8 | 回复: 5 | 点赞: 0 | 发布: 2024-11-18
#   排序: 0.6117 = 0.4 * 0.593（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.573（长度）+ 0.05 * 0.284（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.659（时效）
#   内容: 入住顺利，帮我们升级了行政套房，房间很大，还配备了瑜伽垫，服务周到。卫生间的各项设施完备，餐厅的早餐也不错。不足的地方在于，房间里的电视不能联网。
#   召回路由:
#     • 反向: 第8名(Q1), 第23名(Q0), 第62名(Q1), 第71名(Q0)
#     • 向量: 第9名(Q1), 第27名(Q0)
#     • 文本: 第104名(Q0), 第127名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 8 | 综合得分: 0.5954
#   检索排名: #50 | 检索得分: 0.0183 | Rerank排名: #57 | Rerank得分: 0.4120
#   评论ID: 680278c1e3c98b0941765734
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 8 | 回复: 10 | 点赞: 0 | 发布: 2025-03-14
#   排序: 0.5954 = 0.4 * 0.412（相关）+ 0.25 * 0.800（质量）+ 0.05 * 0.593（长度）+ 0.05 * 0.379（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.910（时效）
#   内容: 趁老公生日的机会，选择在花园酒店度过愉快的一晚，红棉套房套餐体验很好，提前备注酒店帮忙做了生日布置，还送了小蛋糕。各个工作人员都很热情，特别是行政酒廊Louis服务热情。
#   召回路由:
#     • 反向: 第64名(Q0)
#     • 向量: 第68名(Q0)
#     • 文本: 第113名(Q0), 第136名(Q1)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: # 9 | 综合得分: 0.5908
#   检索排名: #66 | 检索得分: 0.0152 | Rerank排名: #13 | Rerank得分: 0.5661
#   评论ID: 68027aa2e3c98b09417658ca
#   房型: 红棉大床套房（套房）
#   评分: 5.0 | 质量: 9 | 回复: 2 | 点赞: 0 | 发布: 2024-08-11
#   排序: 0.5908 = 0.4 * 0.566（相关）+ 0.25 * 0.900（质量）+ 0.05 * 0.611（长度）+ 0.05 * 0.174（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.501（时效）
#   内容: 房间64平，宽敞。服务热情周到。环境优美，装修大气，作为白金五星酒店性价比很高，出行方便，只要不去长隆玩，离广州所有玩的地方，像永庆坊，陈家祠，海心沙，沙面，北京路，圣心大教堂，珠江夜游都不远。
#   召回路由:
#     • 向量: 第45名(Q0)
#     • 反向: 第46名(Q0)
#   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   综合排名: #10 | 综合得分: 0.5890
#   检索排名: #25 | 检索得分: 0.0228 | Rerank排名: # 3 | Rerank得分: 0.7513
#   评论ID: 68027c4be3c98b0941765a37
#   房型: 红棉双床套房（套房）
#   评分: 5.0 | 质量: 7 | 回复: 17 | 点赞: 0 | 发布: 2024-02-07
#   排序: 0.5890 = 0.4 * 0.751（相关）+ 0.25 * 0.700（质量）+ 0.05 * 0.618（长度）+ 0.05 * 0.457（回复）+ 0.05 * 0.000（点赞）+ 0.2 * 0.299（时效）
#   内容: 酒店非常气派，大开眼界！ 长辈都夸好。
# 定的64平的套房，宽敞舒适，客房服务响应及时，行李搬运也到位。
# 第一天图省事去了荔湾艇吃饭，有点不愉快，性价比不高。
# 下次还会选择入住花园酒店，吃饭还是去外面吃更好。
#   召回路由:
#     • 向量: 第22名(Q0)
#     • 反向: 第29名(Q0)
#     • 文本: 第135名(Q0)
